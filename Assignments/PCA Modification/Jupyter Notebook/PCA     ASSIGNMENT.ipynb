# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("wine.csv")

# %%
df
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
# ...

# %%
df.sample(10)
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 30      1    13.73   1.50  2.70        22.5        101     3.00        3.25
# 97      2    12.29   1.41  1.98        16.0         85     2.55        2.50
# 17      1    13.83   1.57  2.62        20.0        115     2.95        3.40
# 127     2    11.79   2.13  2.78        28.5         92     2.13        2.24
# 86      2    12.16   1.61  2.31        22.8         90     1.78        1.69
# 57      1    13.29   1.97  2.68        16.8        102     3.00        3.23
# 82      2    12.08   1.13  2.51        24.0         78     2.00        1.58
# 42      1    13.88   1.89  2.59        15.0        101     3.25        3.56
# 77      2    11.84   2.89  2.23        18.0        112     1.72        1.32
# 65      2    12.37   1.21  2.56        18.1         98     2.42        2.65
#
#      Nonflavanoids  Proanthocyanins  Color   Hue  Dilution  Proline
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Type             178 non-null    int64
#  1   Alcohol          178 non-null    float64
#  2   Malic            178 non-null    float64
#  3   Ash              178 non-null    float64
#  4   Alcalinity       178 non-null    float64
#  5   Magnesium        178 non-null    int64
#  6   Phenols          178 non-null    float64
#  7   Flavanoids       178 non-null    float64
#  8   Nonflavanoids    178 non-null    float64
#  9   Proanthocyanins  178 non-null    float64
#  10  Color            178 non-null    float64
#  11  Hue              178 non-null    float64
#  12  Dilution         178 non-null    float64
#  13  Proline          178 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.6 KB

# %%
df.isnull().sum()
# Out:
# Type               0
# Alcohol            0
# Malic              0
# Ash                0
# Alcalinity         0
# Magnesium          0
# Phenols            0
# Flavanoids         0
# Nonflavanoids      0
# Proanthocyanins    0
# Color              0
# Hue                0
# Dilution           0
# Proline            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#              Type     Alcohol       Malic         Ash  Alcalinity   Magnesium  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean     1.938202   13.000618    2.336348    2.366517   19.494944   99.741573
# std      0.775035    0.811827    1.117146    0.274344    3.339564   14.282484
# min      1.000000   11.030000    0.740000    1.360000   10.600000   70.000000
# 25%      1.000000   12.362500    1.602500    2.210000   17.200000   88.000000
# 50%      2.000000   13.050000    1.865000    2.360000   19.500000   98.000000
# 75%      3.000000   13.677500    3.082500    2.557500   21.500000  107.000000
# max      3.000000   14.830000    5.800000    3.230000   30.000000  162.000000
#
#           Phenols  Flavanoids  Nonflavanoids  Proanthocyanins       Color  \
# count  178.000000  178.000000     178.000000       178.000000  178.000000
# mean     2.295112    2.029270       0.361854         1.590899    5.058090
# ...

# %%
df.shape
# Out:
# (178, 14)

# %%
sns.histplot(x = df["Alcohol"] , kde=True)
# Out:
# <Axes: xlabel='Alcohol', ylabel='Count'>

# %%
sns.boxplot(x = df["Alcohol"])
# Out:
# <Axes: xlabel='Alcohol'>

# %%
 df["Type"].value_counts().plot(kind = "bar")
# Out:
# <Axes: >

# %%
sns.histplot(x=df["Malic"],kde=True)
# Out:
# <Axes: xlabel='Malic', ylabel='Count'>

# %%
sns.boxplot(x=df["Malic"])
# Out:
# <Axes: xlabel='Malic'>

# %%
sns.histplot(x=df["Ash"],kde=True)
# Out:
# <Axes: xlabel='Ash', ylabel='Count'>

# %%
sns.boxplot(x=df["Ash"])
# Out:
# <Axes: xlabel='Ash'>

# %%
sns.histplot(x=df["Alcalinity"],kde=True)
# Out:
# <Axes: xlabel='Alcalinity', ylabel='Count'>

# %%
sns.boxplot(x=df["Alcalinity"])
# Out:
# <Axes: xlabel='Alcalinity'>

# %%
sns.histplot(x=df["Magnesium"],kde=True)
# Out:
# <Axes: xlabel='Magnesium', ylabel='Count'>

# %%
sns.boxplot(x=df["Magnesium"])
# Out:
# <Axes: xlabel='Magnesium'>

# %%
sns.histplot(x=df["Phenols"],kde=True)
# Out:
# <Axes: xlabel='Phenols', ylabel='Count'>

# %%
sns.boxplot(x=df["Phenols"])
# Out:
# <Axes: xlabel='Phenols'>

# %%
sns.histplot(x=df["Flavanoids"],kde=True)
# Out:
# <Axes: xlabel='Flavanoids', ylabel='Count'>

# %%
sns.boxplot(x=df["Flavanoids"])
# Out:
# <Axes: xlabel='Flavanoids'>

# %%
sns.histplot(x=df["Nonflavanoids"])
# Out:
# <Axes: xlabel='Nonflavanoids', ylabel='Count'>

# %%
sns.boxplot(x=df["Nonflavanoids"])
# Out:
# <Axes: xlabel='Nonflavanoids'>

# %%
sns.histplot(x=df["Proanthocyanins"])
# Out:
# <Axes: xlabel='Proanthocyanins', ylabel='Count'>

# %%
sns.boxplot(x=df["Proanthocyanins"])
# Out:
# <Axes: xlabel='Proanthocyanins'>

# %%
sns.histplot(x=df["Color"],kde=True)
# Out:
# <Axes: xlabel='Color', ylabel='Count'>

# %%
sns.boxplot(x=df["Color"])
# Out:
# <Axes: xlabel='Color'>

# %%
sns.histplot(x=df["Hue"])
# Out:
# <Axes: xlabel='Hue', ylabel='Count'>

# %%
sns.histplot(x=df["Hue"],kde=True)
# Out:
# <Axes: xlabel='Hue', ylabel='Count'>

# %%
sns.boxplot(x=df["Hue"])
# Out:
# <Axes: xlabel='Hue'>

# %%
sns.histplot(x=df["Dilution"])
# Out:
# <Axes: xlabel='Dilution', ylabel='Count'>

# %%
sns.histplot(x=df["Dilution"],kde=True)
# Out:
# <Axes: xlabel='Dilution', ylabel='Count'>

# %%
sns.boxplot(x=df["Dilution"])
# Out:
# <Axes: xlabel='Dilution'>

# %%
sns.histplot(x=df["Proline"])
# Out:
# <Axes: xlabel='Proline', ylabel='Count'>

# %%
sns.histplot(x=df["Proline"],kde=True)
# Out:
# <Axes: xlabel='Proline', ylabel='Count'>

# %%
sns.boxplot(x=df["Proline"])
# Out:
# <Axes: xlabel='Proline'>

# %%
df.corr()
# Out:
#                      Type   Alcohol     Malic       Ash  Alcalinity  \
# Type             1.000000 -0.328222  0.437776 -0.049643    0.517859
# Alcohol         -0.328222  1.000000  0.094397  0.211545   -0.310235
# Malic            0.437776  0.094397  1.000000  0.164045    0.288500
# Ash             -0.049643  0.211545  0.164045  1.000000    0.443367
# Alcalinity       0.517859 -0.310235  0.288500  0.443367    1.000000
# Magnesium       -0.209179  0.270798 -0.054575  0.286587   -0.083333
# Phenols         -0.719163  0.289101 -0.335167  0.128980   -0.321113
# Flavanoids      -0.847498  0.236815 -0.411007  0.115077   -0.351370
# Nonflavanoids    0.489109 -0.155929  0.292977  0.186230    0.361922
# Proanthocyanins -0.499130  0.136698 -0.220746  0.009652   -0.197327
# Color            0.265668  0.546364  0.248985  0.258887    0.018732
# Hue             -0.617369 -0.071747 -0.561296 -0.074667   -0.273955
# Dilution        -0.788230  0.072343 -0.368710  0.003911   -0.276769
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
df.describe()
# Out:
#              Type     Alcohol       Malic         Ash  Alcalinity   Magnesium  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean     1.938202   13.000618    2.336348    2.366517   19.494944   99.741573
# std      0.775035    0.811827    1.117146    0.274344    3.339564   14.282484
# min      1.000000   11.030000    0.740000    1.360000   10.600000   70.000000
# 25%      1.000000   12.362500    1.602500    2.210000   17.200000   88.000000
# 50%      2.000000   13.050000    1.865000    2.360000   19.500000   98.000000
# 75%      3.000000   13.677500    3.082500    2.557500   21.500000  107.000000
# max      3.000000   14.830000    5.800000    3.230000   30.000000  162.000000
#
#           Phenols  Flavanoids  Nonflavanoids  Proanthocyanins       Color  \
# count  178.000000  178.000000     178.000000       178.000000  178.000000
# mean     2.295112    2.029270       0.361854         1.590899    5.058090
# ...

# %%
scaler=StandardScaler()

# %%
df_new = pd.DataFrame(data = scaler.fit_transform(df) , columns=df.columns)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components = 5)
pca_values = pca.fit_transform(df_new)
pca_values.shape
# Out:
# (178, 5)

# %%
#loadings or weights
pca.components_
# Out:
# array([[ 0.39366953, -0.13632501,  0.22267638, -0.00225793,  0.22429849,
#         -0.12463016, -0.35926404, -0.39071171,  0.2670012 , -0.2790625 ,
#          0.08931829, -0.27682265, -0.35052618, -0.26951525],
#        [-0.00569041, -0.48416087, -0.22359095, -0.31585588,  0.01161574,
#         -0.30055143, -0.06711983,  0.00131345, -0.0269887 , -0.04122256,
#         -0.52978274,  0.27790735,  0.16277625, -0.36605886],
#        [ 0.00121795, -0.20740081,  0.08879606,  0.62610236,  0.6119896 ,
#          0.13098458,  0.14650775,  0.15096275,  0.16997551,  0.14987959,
#         -0.1372663 ,  0.08532854,  0.16620436, -0.12668685],
#        [ 0.12246373, -0.08191848,  0.46988824, -0.24984122,  0.07199322,
#         -0.16321412,  0.19098521,  0.14461667, -0.32801272,  0.46275771,
#          0.07211248, -0.43466618,  0.15672341, -0.2557949 ],
#        [ 0.15758395, -0.25089415, -0.18860015, -0.0935236 ,  0.0465675 ,
# ...

# %%
# The amount of variance that each PCA explains is 
var = pca.explained_variance_ratio_
var
# Out:
# array([0.39542486, 0.17836259, 0.10329102, 0.06627984, 0.06267875])

# %%
# Cumulative variance 
var1 = np.cumsum(np.round(var,decimals = 4)*100)
var1
# Out:
# array([39.54, 57.38, 67.71, 74.34, 80.61])

# %%
# Variance plot for PCA components obtained 
plt.plot(var1,color="red")

# %%
pca_df = pd.DataFrame(data = pca_values , columns=[f"PCA_{i}" for i in range(5)])

# %%
pca_df
# Out:
#         PCA_0     PCA_1     PCA_2     PCA_3     PCA_4
# 0   -3.522934 -1.453098 -0.164795 -0.013273  0.737345
# 1   -2.528858  0.330019 -2.026707 -0.417144 -0.283214
# 2   -2.785029 -1.036936  0.983238  0.664232 -0.387565
# 3   -3.922588 -2.768210 -0.174968  0.565088 -0.324360
# 4   -1.407511 -0.867773  2.025829 -0.440906  0.227949
# ..        ...       ...       ...       ...       ...
# 173  3.627996 -2.206617 -0.343668  0.751705 -1.004109
# 174  2.942729 -1.752263  0.207480  0.399381  0.154223
# 175  3.027272 -2.756040 -0.940803  0.607758  1.128136
# 176  2.755222 -2.293784 -0.550474 -0.391570  1.067083
# 177  3.496336 -2.760608  1.013151  0.349630 -1.005136
#
# [178 rows x 5 columns]

# %%
from sklearn.cluster import KMeans

# %%
KM = KMeans()

# %%
KM.fit(df_new)
# Out:
# KMeans()

# %%
pd.Series(KM.predict(df_new)).value_counts()
# Out:
# 2    36
# 3    32
# 1    26
# 0    26
# 4    25
# 7    16
# 5    14
# 6     3
# dtype: int64

# %%
wcss = []
for i in range(1,10) :
    KM = KMeans(n_clusters=i , random_state=78)
    KM.fit(df_new)
    wcss.append(KM.inertia_)

# %%
plt.plot(range(1,10), wcss)
plt.title("Elbow Method")
plt.xlabel("Number of clusters")
plt.ylabel("Inertia")
plt.show()

# %%
KM = KMeans(n_clusters=7 , random_state=78)
KM.fit(df_new)
KM_clusters = KM.predict(df_new)

# %%
df_new.plot(x="Alcohol",y ="Color",c=KM.labels_,kind="scatter",s=30 ,cmap=plt.cm.coolwarm) 
plt.title('Clusters using KMeans')
# Out:
# Text(0.5, 1.0, 'Clusters using KMeans')

# %%
df_new.columns
# Out:
# Index(['Type', 'Alcohol', 'Malic', 'Ash', 'Alcalinity', 'Magnesium', 'Phenols',
#        'Flavanoids', 'Nonflavanoids', 'Proanthocyanins', 'Color', 'Hue',
#        'Dilution', 'Proline'],
#       dtype='object')

# %%
sns.scatterplot(data = df_new , x = "Dilution" , y = "Phenols" , hue=KM_clusters)
# Out:
# <Axes: xlabel='Dilution', ylabel='Phenols'>

# %%
pca_df
# Out:
#         PCA_0     PCA_1     PCA_2     PCA_3     PCA_4
# 0   -3.522934 -1.453098 -0.164795 -0.013273  0.737345
# 1   -2.528858  0.330019 -2.026707 -0.417144 -0.283214
# 2   -2.785029 -1.036936  0.983238  0.664232 -0.387565
# 3   -3.922588 -2.768210 -0.174968  0.565088 -0.324360
# 4   -1.407511 -0.867773  2.025829 -0.440906  0.227949
# ..        ...       ...       ...       ...       ...
# 173  3.627996 -2.206617 -0.343668  0.751705 -1.004109
# 174  2.942729 -1.752263  0.207480  0.399381  0.154223
# 175  3.027272 -2.756040 -0.940803  0.607758  1.128136
# 176  2.755222 -2.293784 -0.550474 -0.391570  1.067083
# 177  3.496336 -2.760608  1.013151  0.349630 -1.005136
#
# [178 rows x 5 columns]

# %%
from sklearn.cluster import KMeans

# %%
KM = KMeans()

# %%
KM.fit(pca_df)
# Out:
# KMeans()

# %%
pd.Series(KM.predict(pca_df)).value_counts()
# Out:
# 1    34
# 0    33
# 4    23
# 5    22
# 2    22
# 7    22
# 3    16
# 6     6
# dtype: int64

# %%
wcss = []
for i in range(1,10) :
    KM = KMeans(n_clusters=i , random_state=78)
    KM.fit(pca_df)
    wcss.append(KM.inertia_)

# %%
plt.plot(range(1,10), wcss)
plt.title("Elbow Method")
plt.xlabel("Number of clusters")
plt.ylabel("Inertia")
plt.show()

# %%
KM = KMeans(n_clusters=4 , random_state=78)
KM.fit(pca_df)
PCA_clusters = KM.predict(pca_df)

# %%
sns.scatterplot(data = pca_df , x = "PCA_0" , y = "PCA_1" , hue=PCA_clusters)
# Out:
# <Axes: xlabel='PCA_0', ylabel='PCA_1'>

# %%
sns.scatterplot(data = pca_df , x = "PCA_0" , y = "PCA_4" , hue=PCA_clusters)
# Out:
# <Axes: xlabel='PCA_0', ylabel='PCA_4'>

# %%
from scipy.cluster.hierarchy import linkage 
import scipy.cluster.hierarchy as sch # for creating dendrogram 
#p = np.array(df_norm) # converting into numpy array format 
z = linkage(df_new, method="average",metric="euclidean")
plt.figure(figsize=(15, 5))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Index')
plt.ylabel('Distance')
sch.dendrogram(
    z,
    #leaf_rotation=6.,  # rotates the x axis labels
    #leaf_font_size=15.,  # font size for the x axis labels
)
plt.show()

# %%
from scipy.cluster.hierarchy import linkage 
import scipy.cluster.hierarchy as sch # for creating dendrogram 
#p = np.array(df_norm) # converting into numpy array format 
z = linkage(df_new, method="single",metric="euclidean")
plt.figure(figsize=(15, 5))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Index')
plt.ylabel('Distance')
sch.dendrogram(
    z,
    #leaf_rotation=0.,  # rotates the x axis labels
    #leaf_font_size=8.,  # font size for the x axis labels
)
plt.show()

# %%
from scipy.cluster.hierarchy import linkage 
import scipy.cluster.hierarchy as sch # for creating dendrogram 
#p = np.array(df_norm) # converting into numpy array format 
z = linkage(df_new, method="complete",metric="euclidean")
plt.figure(figsize=(15, 5))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Index')
plt.ylabel('Distance')
sch.dendrogram(
    z,
    #leaf_rotation=0.,  # rotates the x axis labels
    #leaf_font_size=8.,  # font size for the x axis labels
)
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
h_complete = AgglomerativeClustering(n_clusters=6, linkage='complete',affinity = "euclidean").fit(df_new) 

cluster_labels=pd.Series(h_complete.labels_)
cluster_labels
# Out:
# 0      4
# 1      4
# 2      4
# 3      4
# 4      1
#       ..
# 173    0
# 174    0
# 175    0
# 176    0
# 177    0
# Length: 178, dtype: int64

# %%
sns.scatterplot(data = df_new , x = "Dilution" , y = "Phenols" , hue=cluster_labels)
# Out:
# <Axes: xlabel='Dilution', ylabel='Phenols'>

# %%
from scipy.cluster.hierarchy import linkage 
import scipy.cluster.hierarchy as sch # for creating dendrogram 
#p = np.array(df_norm) # converting into numpy array format 
z = linkage(pca_df, method="average",metric="euclidean")
plt.figure(figsize=(15, 5))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Index')
plt.ylabel('Distance')
sch.dendrogram(
    z,
    #leaf_rotation=6.,  # rotates the x axis labels
    #leaf_font_size=15.,  # font size for the x axis labels
)
plt.show()

# %%
from scipy.cluster.hierarchy import linkage 
import scipy.cluster.hierarchy as sch # for creating dendrogram 
#p = np.array(df_norm) # converting into numpy array format 
z = linkage(pca_df, method="single",metric="euclidean")
plt.figure(figsize=(15, 5))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Index')
plt.ylabel('Distance')
sch.dendrogram(
    z,
    #leaf_rotation=0.,  # rotates the x axis labels
    #leaf_font_size=8.,  # font size for the x axis labels
)
plt.show()

# %%
from scipy.cluster.hierarchy import linkage 
import scipy.cluster.hierarchy as sch # for creating dendrogram 
#p = np.array(df_norm) # converting into numpy array format 
z = linkage(pca_df, method="complete",metric="euclidean")
plt.figure(figsize=(15, 5))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Index')
plt.ylabel('Distance')
sch.dendrogram(
    z,
    #leaf_rotation=0.,  # rotates the x axis labels
    #leaf_font_size=8.,  # font size for the x axis labels
)
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
h_complete = AgglomerativeClustering(n_clusters=4, linkage='complete',affinity = "euclidean").fit(pca_df) 

cluster_labels=pd.Series(h_complete.labels_)
cluster_labels
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 173    2
# 174    2
# 175    2
# 176    2
# 177    2
# Length: 178, dtype: int64

# %%
sns.scatterplot(data = pca_df , x = "PCA_0" , y = "PCA_1" , hue=cluster_labels)
# Out:
# <Axes: xlabel='PCA_0', ylabel='PCA_1'>

# %%
sns.scatterplot(data = pca_df , x = "PCA_0" , y = "PCA_4" , hue=cluster_labels)
# Out:
# <Axes: xlabel='PCA_0', ylabel='PCA_4'>

# %%
from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps=2.1, min_samples=4)
dbscan.fit(df_new)
pd.Series(dbscan.labels_).value_counts()
# Out:
# -1    57
#  0    50
#  1    34
#  3    24
#  2    13
# dtype: int64

# %%
pca_df.shape
# Out:
# (178, 5)

# %%
sns.scatterplot(data = df_new , x = "Dilution" , y = "Phenols" , hue=dbscan.labels_)
# Out:
# <Axes: xlabel='Dilution', ylabel='Phenols'>

# %%
from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps=1.4, min_samples=4)
dbscan.fit(pca_df)
pd.Series(dbscan.labels_).value_counts()
# Out:
#  0    55
#  1    47
#  2    37
# -1    32
#  3     7
# dtype: int64

# %%
sns.scatterplot(data = pca_df , x = "PCA_0" , y = "PCA_4" , hue=dbscan.labels_)
# Out:
# <Axes: xlabel='PCA_0', ylabel='PCA_4'>

# %%
sns.scatterplot(data = pca_df , x = "PCA_0" , y = "PCA_1" , hue=dbscan.labels_)
# Out:
# <Axes: xlabel='PCA_0', ylabel='PCA_1'>

# %%
#when we applied k mean clustering on the orginal dataset, the elbow curve shows 7 cluster ,but when i applied PCA the Elbow curve shows 3 cluster....
#orginal dataset performance is not good but when i applied pca performance of dataset is better ...
#when i look at the clusters in original dataset the cluster are not clearly visible because orginal data is large 
#but when i applied Pca cluster are visible properly...
