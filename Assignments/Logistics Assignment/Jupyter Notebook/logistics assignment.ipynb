# %%
import pandas as pd 
import numpy as np 
import matplotlib .pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv("Titanic_train.csv")

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df1.drop(["PassengerId"],inplace=True,axis = 1)

# %%
df1.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df1.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 76.7+ KB

# %%
df1["Cabin"].value_counts()
# Out:
# Cabin
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: count, Length: 147, dtype: int64

# %%
df1["Cabin"].mode()
# Out:
# 0        B96 B98
# 1    C23 C25 C27
# 2             G6
# Name: Cabin, dtype: object

# %%
df1.drop("Cabin", axis=1,inplace=True)

# %%
mera_mean1 = df1.Age.mean()

# %%
mera_mean1
# Out:
# 29.69911764705882

# %%
df1.Age.fillna(mera_mean1 , inplace=True)

# %%
df1.Age.mean()
# Out:
# 29.69911764705882

# %%
df1.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Embarked    2
# dtype: int64

# %%
dd=df1.Embarked.mode() 
dd
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
dd[0]
# Out:
# 'S'

# %%
df1.Embarked.fillna(dd[0],inplace=True)

# %%
df1.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Embarked    0
# dtype: int64

# %%
#sns.countplot(df1["Survived"])
df1["Survived"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Survived'>

# %%
df1["Pclass"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Pclass'>

# %%
df1["Embarked"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Embarked'>

# %%
plt.hist(df1["Age"])
# Out:
# (array([ 54.,  46., 177., 346., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
sns.displot(df1["Age"],kde=True)
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.boxplot(df1["Fare"])
# Out:
# <Axes: >

# %%
sns.boxplot(df1['Age'])
# Out:
# <Axes: >

# %%
sns.pairplot(df1)
plt.show()
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df1.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Embarked    0
# dtype: int64

# %%
df1.drop("Name", axis=1,inplace=True)

# %%
df1.drop("Ticket", axis=1,inplace=True)

# %%
df1.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
df1 = pd.get_dummies(df1 , columns=["Sex", "Embarked"], drop_first=True ,dtype=np.int32 )

# %%
df1.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  Sex_male  Embarked_Q  \
# 0         0       3  22.0      1      0   7.2500         1           0
# 1         1       1  38.0      1      0  71.2833         0           0
# 2         1       3  26.0      0      0   7.9250         0           0
# 3         1       1  35.0      1      0  53.1000         0           0
# 4         0       3  35.0      0      0   8.0500         1           0
#
#    Embarked_S
# 0           1
# 1           0
# 2           1
# 3           1
# 4           1

# %%
X = df1.drop("Survived" , axis = 1)

# %%
y = df1["Survived"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# %%
SS = StandardScaler()

# %%
for i in ["Age" , "Fare"] :
    X_train[i] = SS.fit_transform(X_train[[i]])
    X_test[i] = SS.transform(X_test[[i]])

# %%
X_train.head()
# Out:
#      Pclass       Age  SibSp  Parch      Fare  Sex_male  Embarked_Q  \
# 6         1  1.889570      0      0  0.387842         1           0
# 718       3  0.010736      0      0 -0.319081         1           1
# 685       2 -0.352579      1      2  0.187924         1           0
# 73        3 -0.275263      1      0 -0.339412         1           0
# 882       3 -0.584525      0      0 -0.415961         0           0
#
#      Embarked_S
# 6             1
# 718           0
# 685           0
# 73            0
# 882           1

# %%
from sklearn.linear_model import LogisticRegression

# %%
LogR = LogisticRegression()

# %%
LogR.fit(X_train , y_train)
# Out:
# LogisticRegression()

# %%
train_pred = LogR.predict(X_train)

# %%
test_pred = LogR.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix , accuracy_score , classification_report , ConfusionMatrixDisplay , roc_curve

# %%
print(classification_report(y_train , train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.87      0.85       374
#            1       0.76      0.68      0.72       222
#
#     accuracy                           0.80       596
#    macro avg       0.79      0.78      0.78       596
# weighted avg       0.80      0.80      0.80       596

# %%
# cm = confusion_matrix(y_train , train_pred)
print("Confusion Metrix for Training Data")
cm = confusion_matrix(y_train, train_pred, labels=LogR.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=LogR.classes_)
disp.plot()
plt.show()
# Out:
# Confusion Metrix for Training Data

# %%
# cm = confusion_matrix(y_train , train_pred)
print("Confusion Metrix for testing Data")
cm = confusion_matrix(y_test, test_pred, labels=LogR.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=LogR.classes_)
disp.plot()
plt.show()
# Out:
# Confusion Metrix for testing Data

# %%
print("Accuracy score for training Data : ", round(accuracy_score(y_train , train_pred),2))
# Out:
# Accuracy score for training Data :  0.8

# %%
print("Accuracy score for testing Data : ", round(accuracy_score(y_test , test_pred),2))
# Out:
# Accuracy score for testing Data :  0.81

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# %%
print("Roc Curve for training Data")
Logit_roc_score=roc_auc_score(y_train , train_pred)
fpr, tpr, thresholds = roc_curve(y_train,LogR.predict_proba(X_train)[:,1]) 
plt.plot(fpr, tpr, label='Logistic Regression (area=%0.2f)'% Logit_roc_score)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# Roc Curve for training Data

# %%
print("Roc Curve for testing Data")
Logit_roc_score=roc_auc_score(y_train , train_pred)
fpr, tpr, thresholds = roc_curve(y_test,LogR.predict_proba(X_test)[:,1]) 
plt.plot(fpr, tpr, label='Logistic Regression (area=%0.2f)'% Logit_roc_score)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# Roc Curve for testing Data

# %%
LogR.coef_
# Out:
# array([[-0.85827193, -0.3640073 , -0.26782978, -0.08948252,  0.14667672,
#         -2.44212877, -0.19594546, -0.60985561]])

# %%
X_train.columns
# Out:
# Index(['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Sex_male', 'Embarked_Q',
#        'Embarked_S'],
#       dtype='object')

# %%
pd.DataFrame(data = LogR.coef_ , columns=X_train.columns)
# Out:
#      Pclass       Age    SibSp     Parch      Fare  Sex_male  Embarked_Q  \
# 0 -0.858272 -0.364007 -0.26783 -0.089483  0.146677 -2.442129   -0.195945
#
#    Embarked_S
# 0   -0.609856
