# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel("glass.xlsx",sheet_name="glass")

# %%
df
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %%
df.sample(10)
# Out:
#           RI     Na    Mg    Al     Si     K     Ca    Ba    Fe  Type
# 26   1.51793  13.21  3.48  1.41  72.64  0.59   8.43  0.00  0.00     1
# 109  1.51818  13.72  0.00  0.56  74.45  0.00  10.99  0.00  0.00     2
# 93   1.51590  13.24  3.34  1.47  73.10  0.39   8.22  0.00  0.00     2
# 63   1.52227  14.17  3.81  0.78  71.35  0.00   9.69  0.00  0.00     1
# 38   1.52213  14.21  3.82  0.47  71.77  0.11   9.57  0.00  0.00     1
# 163  1.51514  14.01  2.68  3.50  69.89  1.68   5.87  2.20  0.00     5
# 44   1.51786  12.73  3.43  1.19  72.95  0.62   8.76  0.00  0.30     1
# 19   1.51735  13.02  3.54  1.69  72.73  0.54   8.44  0.00  0.07     1
# 205  1.51732  14.95  0.00  1.80  72.99  0.00   8.61  1.55  0.00     7
# 168  1.51666  12.86  0.00  1.83  73.88  0.97  10.17  0.00  0.00     5

# %%
df.isnull().sum()
# Out:
# RI      0
# Na      0
# Mg      0
# Al      0
# Si      0
# K       0
# Ca      0
# Ba      0
# Fe      0
# Type    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RI      214 non-null    float64
#  1   Na      214 non-null    float64
#  2   Mg      214 non-null    float64
#  3   Al      214 non-null    float64
#  4   Si      214 non-null    float64
#  5   K       214 non-null    float64
#  6   Ca      214 non-null    float64
#  7   Ba      214 non-null    float64
#  8   Fe      214 non-null    float64
#  9   Type    214 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB

# %%
df.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516522   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009    2.780374
# std      1.423153    0.497219    0.097439    2.103739
# ...

# %%
df.shape
# Out:
# (214, 10)

# %%
df[df.duplicated()]
# Out:
#          RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 39  1.52213  14.21  3.82  0.47  71.77  0.11  9.57  0.0  0.0     1

# %%
df = df.drop_duplicates() # Removed the duplicate value
df = df.reset_index(drop=True)

# %%
sns.histplot(df["RI"] , kde=True)
# Out:
# <Axes: xlabel='RI', ylabel='Count'>

# %%
sns.histplot(df["Na"] , kde=True)
# Out:
# <Axes: xlabel='Na', ylabel='Count'>

# %%
sns.histplot(df["Mg"] , kde=True)
# sns.histplot(df["Mg"].apply(np.log2),kde = True)
# Out:
# <Axes: xlabel='Mg', ylabel='Count'>

# %%
sns.histplot(df["Al"] , kde=True)
# Out:
# <Axes: xlabel='Al', ylabel='Count'>

# %%
sns.histplot(df["Si"] , kde=True)
# Out:
# <Axes: xlabel='Si', ylabel='Count'>

# %%
sns.histplot(df["K"] , kde=True)
# Out:
# <Axes: xlabel='K', ylabel='Count'>

# %%
sns.histplot(df["K"].apply(lambda x : np.log2(x+0.01)),kde = True)
# Out:
# <Axes: xlabel='K', ylabel='Count'>

# %%
df["K"] = df["K"].apply(lambda x : np.log2(x+0.01))

# %%
sns.histplot(df["Ca"] , kde=True)
# Out:
# <Axes: xlabel='Ca', ylabel='Count'>

# %%
sns.histplot(df["Ba"] , kde=True)
# Out:
# <Axes: xlabel='Ba', ylabel='Count'>

# %%
sns.histplot(df["Ba"].apply(lambda x : np.log2(x+1)),kde = True)
# df = df.drop("Ba" , axis =1)
# Out:
# <Axes: xlabel='Ba', ylabel='Count'>

# %%
sns.histplot(df["Fe"] , kde=True)
# Out:
# <Axes: xlabel='Fe', ylabel='Count'>

# %%
sns.histplot(df["Fe"].apply(lambda x : np.log2(x+0.01)),kde = True)
# Out:
# <Axes: xlabel='Fe', ylabel='Count'>

# %%
# df["Fe"] = df["Fe"].apply(np.log2)

# %%
sns.boxplot(x = df["RI"])
# Out:
# <Axes: xlabel='RI'>

# %%
sns.boxplot(x = df["Na"])
# Out:
# <Axes: xlabel='Na'>

# %%
sns.boxplot(x = df["Mg"])
# Out:
# <Axes: xlabel='Mg'>

# %%
sns.boxplot(x = df["Al"])
# Out:
# <Axes: xlabel='Al'>

# %%
sns.boxplot(x = df["Si"])
# Out:
# <Axes: xlabel='Si'>

# %%
sns.boxplot(x = df["K"])
# Out:
# <Axes: xlabel='K'>

# %%
sns.boxplot(x = df["Ca"])
# Out:
# <Axes: xlabel='Ca'>

# %%
sns.boxplot(x = df["Ba"])
# Out:
# <Axes: xlabel='Ba'>

# %%
# df.drop(["Ba"],inplace=True,axis = 1)

# %%
df
# Out:
#           RI     Na    Mg    Al     Si         K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78 -3.836501  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73 -1.029146  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99 -1.321928  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61 -0.785875  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08 -0.836501  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...       ...   ...   ...  ...   ...
# 208  1.51623  14.14  0.00  2.88  72.61 -3.473931  9.18  1.06  0.0     7
# 209  1.51685  14.92  0.00  1.99  73.06 -6.643856  8.40  1.59  0.0     7
# 210  1.52065  14.36  0.00  2.02  73.42 -6.643856  8.44  1.64  0.0     7
# 211  1.51651  14.38  0.00  1.94  73.61 -6.643856  8.48  1.57  0.0     7
# 212  1.51711  14.23  0.00  2.08  73.36 -6.643856  8.62  1.67  0.0     7
#
# [213 rows x 10 columns]

# %%
sns.boxplot(x = df["Fe"])
# Out:
# <Axes: xlabel='Fe'>

# %%
# sns.pairplot(df)
# plt.show()

# %%
sns.scatterplot(x=df["Mg"],y=df["Si"])
# Out:
# <Axes: xlabel='Mg', ylabel='Si'>

# %%
sns.scatterplot(x=df["K"],y=df["Ca"])
# Out:
# <Axes: xlabel='K', ylabel='Ca'>

# %%
sns.scatterplot(x=df["Mg"],y=df["RI"])
# Out:
# <Axes: xlabel='Mg', ylabel='RI'>

# %%
X = df.drop("Type" , axis = 1)

# %%
y = df["Type"]

# %%
y.value_counts()
# Out:
# 2    76
# 1    69
# 7    29
# 3    17
# 5    13
# 6     9
# Name: Type, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
SS_X = scaler.fit_transform(X)
SS_X = pd.DataFrame(SS_X)
SS_X.columns = X.columns
SS_X.head()
# Out:
#          RI        Na        Mg        Al        Si         K        Ca  \
# 0  0.879840  0.289558  1.257238 -0.706370 -1.133248 -0.859213 -0.143466
# 1 -0.243816  0.596403  0.639311 -0.180863  0.097037  0.425526 -0.790201
# 2 -0.716412  0.154546  0.604596  0.182950  0.433746  0.291540 -0.825349
# 3 -0.227291 -0.238216  0.701798 -0.322346 -0.058368  0.536855 -0.516041
# 4 -0.306608 -0.164573  0.653197 -0.423405  0.550299  0.513687 -0.621487
#
#          Ba        Fe
# 0 -0.353808 -0.588301
# 1 -0.353808 -0.588301
# 2 -0.353808 -0.588301
# 3 -0.353808 -0.588301
# 4 -0.353808 -0.588301

# %%
from sklearn.ensemble import RandomForestClassifier
RF = RandomForestClassifier(n_estimators=200, max_samples=0.8, max_features=0.8,random_state=42)
RF.fit(X_train, y_train)

y_pred_train = RF.predict(X_train)
y_pred_test = RF.predict(X_test)

from sklearn.metrics import accuracy_score
train_accuracy = accuracy_score(y_train, y_pred_train)
test_accuracy = accuracy_score(y_test, y_pred_test)

print("RF - Training Accuracy:", train_accuracy)
print("RF - Testing Accuracy:", test_accuracy)
# Out:
# RF - Training Accuracy: 1.0
# RF - Testing Accuracy: 0.7906976744186046

# %%
from sklearn.ensemble import BaggingClassifier
bagging = BaggingClassifier(estimator=None, n_estimators=200, max_samples=0.8, max_features=0.8,random_state=42)
bagging.fit(X_train, y_train)

y_pred_train = bagging.predict(X_train)
y_pred_test = bagging.predict(X_test)

from sklearn.metrics import accuracy_score
train_accuracy = accuracy_score(y_train, y_pred_train)
test_accuracy = accuracy_score(y_test, y_pred_test)

print("Bagging - Training Accuracy:", train_accuracy)
print("Bagging - Testing Accuracy:", test_accuracy)
# Out:
# Bagging - Training Accuracy: 1.0
# Bagging - Testing Accuracy: 0.7674418604651163

# %%
from sklearn.metrics import confusion_matrix , accuracy_score , classification_report , ConfusionMatrixDisplay , roc_curve , f1_score
y_test_pred = RF.predict(X_test)
y_train_pred = RF.predict(X_train)

cm = confusion_matrix(y_train , y_train_pred)
print("Confusion Metrix for Training Data")
cm = confusion_matrix(y_train, y_train_pred, labels=RF.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=RF.classes_)
disp.plot()
plt.show()
# Out:
# Confusion Metrix for Training Data

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
boosting = AdaBoostClassifier(estimator=None, n_estimators=50,random_state=42)
boosting.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(random_state=42)

# %%
y_pred_train = boosting.predict(X_train)
y_pred_test = boosting.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
train_accuracy = accuracy_score(y_train, y_pred_train)
test_accuracy = accuracy_score(y_test, y_pred_test)

# %%
print("Boosting - Training Accuracy:", train_accuracy)
print("Boosting - Testing Accuracy:", test_accuracy)
# Out:
# Boosting - Training Accuracy: 0.4235294117647059
# Boosting - Testing Accuracy: 0.4186046511627907

# %%
boosting.feature_importances_
# Out:
# array([0.  , 0.  , 0.48, 0.28, 0.  , 0.22, 0.  , 0.02, 0.  ])
